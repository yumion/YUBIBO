# %%
import serial
import numpy as np
import os
import time

# %%
import struct, binascii

def parseTWELite(data):

    data = data[1:]
    
    ss = struct.Struct('>BBBBBIBHBHBBBBBBBBB')
    data = binascii.unhexlify(data.rstrip())
    parsed = ss.unpack(data)
    
    digital = [0] * 4
    digitalchanged = [0] * 4
    analog = [0xffff] * 4
    
    for i in range(4):
        if parsed[11] & (1 << i):
            digital[i] = 1
        else:
            digital[i] = 0
        if parsed[12] & 1<< i:
            digitalchanged[i] = 1
        else:
            digitalchanged[i] = 0
        
        if parsed[13+i] == 0xff:
            analog[i] = 0xffff
        else:
            analog[i] = (parsed[13+i] * 4 + ((parsed[17] >> (2<<i)) & 3 )) * 4
    
    result = {'from': parsed[0], 
              'lqi': parsed[4], 
              'fromid': parsed[5], 
              'to': parsed[6], 
              'timestamp': parsed[7], 
              'isrelay': parsed[8], 
              'battery': parsed[9], 
              'digital': digital, 
              'digitalchanged': digitalchanged,
              'analog': analog}
    
    return result

# %%
s = serial.Serial('/dev/cu.usbserial-MW2UQ1WS', 115200)

# %%
data = s.readline()
parsed = parseTWELite(data)

# %%
parsed
# Out:
# {'analog': [748, 65535, 65535, 65535],
#  'battery': 2096,
#  'digital': [0, 0, 0, 0],
#  'digitalchanged': [0, 0, 0, 0],
#  'from': 120,
#  'fromid': 2165072068,
#  'isrelay': 0,
#  'lqi': 195,
#  'timestamp': 1009,
#  'to': 0}

# %%
while True:
    data = s.readline()
    parsed  =parseTWELite(data)
    print('vol:', parsed['analog'][0])
    time.sleep(1)
# Out:
# vol: 748
# vol: 748
# vol: 748
# vol: 748
# vol: 748
# vol: 748
# vol: 748
# vol: 748
# vol: 748
# vol: 748
# vol: 748
# vol: 748
# vol: 716
# vol: 764
# vol: 748
# vol: 732
# vol: 748
# vol: 764
# vol: 668
# vol: 588
# vol: 652
# vol: 716
# vol: 764
# vol: 764
# vol: 732
# vol: 748
# vol: 716
# vol: 780
# vol: 732
# vol: 812
# vol: 876
# vol: 972
# vol: 1052
# vol: 1036
# vol: 1036
# vol: 1036
# vol: 1036
# vol: 1036
# vol: 1036
# vol: 1036
# vol: 844
# vol: 668
# vol: 556
# vol: 444
# vol: 508
# vol: 652
# vol: 732
# vol: 860
# vol: 972
# vol: 844
# vol: 732
# vol: 604
# vol: 524
# vol: 604
# vol: 684
# vol: 604
# vol: 972
# vol: 780
# vol: 684
# vol: 636
# vol: 588
# vol: 652
# vol: 764
# vol: 700
# vol: 620
# vol: 684
# vol: 780
# vol: 652
# vol: 796
# vol: 684
# vol: 732
# vol: 812
# vol: 748
# vol: 588
# vol: 492
# vol: 588
# vol: 668
# vol: 524
# vol: 380
# vol: 188
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 108
# vol: 236
# vol: 332
# vol: 444
# vol: 524
# vol: 604
# vol: 684
# vol: 764
# vol: 860
# vol: 940
# vol: 860
# vol: 940
# vol: 1020
# vol: 1020
# vol: 1020
# vol: 1020
# vol: 1020
# vol: 1020
# vol: 1020
# vol: 1020
# vol: 1020
# vol: 1016
# vol: 1016
# vol: 1016
# vol: 1016
# vol: 1016
# vol: 1012
# vol: 1008
# vol: 1008
# vol: 1008
# vol: 1020
# vol: 1004
# vol: 1000
# vol: 1000
# vol: 1012
# vol: 1000
# vol: 1016
# vol: 1000
# vol: 808
# vol: 600
# vol: 424
# vol: 312
# vol: 396
# vol: 508
# vol: 584
# vol: 668
# vol: 2036
# vol: 2024
# vol: 2040
# vol: 2036
# vol: 2032
# vol: 2032
# vol: 2032
# vol: 2040
# vol: 2032
# vol: 2032
# vol: 2040
# vol: 2032
# vol: 2032
# vol: 2032
# vol: 2028
# vol: 2040
# vol: 2040
# vol: 2044
# vol: 2032
# vol: 2036
# vol: 2032
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 65535
# vol: 1916
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1164
# vol: 1084
# vol: 1132
# vol: 956
# vol: 444
# vol: 748
# vol: 876
# vol: 460
# vol: 844
# vol: 1020
# vol: 444
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# vol: 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-13560bd1cb81> in <module>()
#       3     parsed  =parseTWELite(data)
#       4     print('vol:', parsed['analog'][0])
# ----> 5     time.sleep(1)
#
# KeyboardInterrupt:
